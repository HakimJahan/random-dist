# %% [markdown]
# # Random Distribution

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
N = 10000
data = np.zeros(N)
for i in range(N):
    data[i]= np.mean(np.random.rand(10))

# %%
n, bins = np.histogram(data, 100)
mean = 0.5*(bins[1:]+bins[:-1])

# %%
def func(x, a, b, c):
    return a*np.exp(-(x-b)**2/(2*c))

params, p_cov = curve_fit(func, mean, n)

a=np.sum(mean*n)/np.sum(n)
b=np.sum(mean**2*n)/np.sum(n)
sigma = b - a**2

# %% [markdown]
# ## Discription
#
# For Curve Fitting, we have used function $f(x) = a\exp^{(-\frac{(x-b)^2}{2c})}$, where $a,\;b$ and $c$ are arbitrary constant.

# %%
plt.figure()
plt.hist(data,100, label='Average Random No')
plt.plot(mean, func(mean, *params), label='Fit')
plt.xlabel('Indices')
plt.ylabel('Frequency')
plt.legend()
plt.title('Gaussian Distribution')
#plt.grid('true')
plt.savefig('fig.pdf', bbox_inches='tight')
plt.show()

# %%
print('Fit \t\t\t: Mean = %0.6f, Variance = %0.6f'%(params[1], params[2]))
print('Calculated Values \t: Mean = %0.6f, Variance = %0.6f'%(a, sigma))
# Out:
# Fit 			: Mean = 0.500194, Variance = 0.008789
# Calculated Values 	: Mean = 0.500094, Variance = 0.008368
